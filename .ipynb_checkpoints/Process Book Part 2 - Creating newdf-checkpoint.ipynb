# %% [markdown]
# <h2 align = 'center'> Creating the newdf dataframe </h2>
#
# Once we got all the match objects into a folder (4.3 GB of data), the next step is to extract all the data that we want from each match, and discard the rest. In order to do this, we have to decide which variables in-game we think might possibly be important. After much discussion, analysis of games, and personal experience playing the game, here are the metrics we believed to have possible significance over determining win/loss. All of these factors were determined based on the fact that these features gave either team (when accomplished) an advantage that helped them towards the ultimate goal of taking down the Nexus.
#
# | Name | Description (All differences are blue team - red team)
# | :- |-------------:
# |Diffcc| Difference in the amount of "crowd control" applied (a mechanic that immobilizes enemies)
# |Diffdmg| Difference in total damage dealt by each team
# |Diffgold| Difference in total gold earned per team
# |Diffkda| Difference in the kill-death-assist ratio of each team
# |Diffrange| Difference in number of ranged champions on each team
# |Diffspree| Difference in number of times there was a killing streak
# |Difftank| Difference in the number of "tank" champions on the each team
# |Diffdrag| Difference in the number of dragons (a neutral objective) slain
# |Diffbaron| Difference in the number of barons (a much more powerful neutral objective) slain
# |Difftp| Difference in the number of champions who took the "teleport" summoners spell
# |Fblood| Which team got the first kill of the game
# |Fdrag| Which team took down the first dragon of the game
# |Finhib| Which team took down the first inhib of the game
# |Fturret| Which team took down the first turret of the game
# |Fbaron| Which team took down the first baron the game
# |Diffcs| Difference in creep score of each team (creep score is the number of AI-controlled minions killed)
# |Win (dependent variable)| Which team won or lost (1 for blue win, 0 for red win)
#
# What we quickly realized after running some analysis on the data was that simply having post-game metrics do determine game wins/losses was not very helpful in understanding what dynamics of the game influence victory. In other words, a lot of the interpretation we were able to make using post-game data was a bit obvious (we'll talk more on this in our analysis part). For now, we saved the generated csv file into the file "newdf."
#
# Please note that you must obtain your own api key and replace it in the "YOUR_API_KEY_HERE' portion in the code below.

# %%
# %matplotlib inline
import numpy as np
import scipy as sp
import matplotlib as mpl
import matplotlib.cm as cm
import matplotlib.pyplot as plt
import pandas as pd
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)
pd.set_option('display.notebook_repr_html', True)
import seaborn as sns
sns.set_style("whitegrid")
sns.set_context("poster")
from cassiopeia import riotapi as ra
from cassiopeia.type.core.common import Queue
import pickle
import os
import time
# use personal API key given by Riot Games
ra.set_api_key('YOUR_API_KEY_HERE')
# all games will be taken from the North American server
ra.set_region('NA')
# the folder in which all of the data is held
path = 'match_data'

# %%
# initialize all column values
fblood = []
fdrag = []
finhib = []
fturret = []
fbaron = []
diffdrag = []
diffbaron = []
diffcs = []
diffkda = []
diffcc = []
diffspree = []
diffgold = []
diffdmg = []
difftank = []
diffrange = []
difftp = []
win = []

# %%
# list of column names
colnames = ['fblood','fdrag','finhib','fturret','fbaron','diffdrag','diffbaron','diffcs','diffkda','diffcc',
            'diffspree','diffgold','diffdmg','difftank','diffrange', 'difftp', 'win']
print(colnames, len(colnames))
# Out:
# ['fblood', 'fdrag', 'finhib', 'fturret', 'fbaron', 'diffdrag', 'diffbaron', 'diffcs', 'diffkda', 'diffcc', 'diffspree', 'diffgold', 'diffdmg', 'difftank', 'diffrange', 'difftp', 'win'] 17

# %%
# loops through all 20000 matches in the folder
for filename in os.listdir(path):
    with open(path + '\\' + filename, 'rb') as f:
        match = pickle.load(f)
    print("Processing match", match.id)

    # for all indicator variables, 1=blue and 0=red
    # for all difference values, positive=blue and negative=red
    
    ## INDICATOR VARIABLES
    # winner
    win.append(match.blue_team.win)
    # first blood
    fblood.append(match.blue_team.first_blood)
    # first dragon
    fdrag.append(match.blue_team.first_dragon)
    # first inhib
    finhib.append(match.blue_team.first_inhibitor)
    # first turret
    fturret.append(match.blue_team.first_turret)
    # first baron
    fbaron.append(match.blue_team.first_baron)

    # difference in number of dragons killed
    diffdrag.append(match.blue_team.dragon_kills - match.red_team.dragon_kills)
    # difference in number of barons killed
    diffbaron.append(match.blue_team.baron_kills - match.red_team.baron_kills)
    
    # various team sums or averages of individual player stats (e.g. creep score, kda, gold earned, etc.)
    blueteamchamps = []
    redteamchamps = []
    bcs = 0
    rcs = 0
    bkda = 0
    rkda = 0
    bcc = 0
    rcc = 0
    bspree = 0
    rspree = 0
    bgold = 0
    rgold = 0
    bdmg = 0
    rdmg = 0
    bss = []
    rss = []
    
    # loop through each player in blue team to find total stats for blue
    for participant in match.blue_team.participants:
        # creep score
        bcs = bcs + participant.stats.minion_kills + participant.stats.monster_kills
        # kda
        bkda = bkda + participant.stats.kda
        # crowd control dealt
        bcc = bcc + participant.stats.crowd_control_dealt
        # number of killing sprees
        bspree = bspree + participant.stats.killing_sprees
        # total gold earned
        bgold = bgold + participant.stats.gold_earned
        # total damage dealt to champions
        bdmg = bdmg + participant.stats.damage_dealt_to_champions
        # list of summoner spells to mark Teleport later on in the code
        if participant.summoner_spell_d is not None:
            bss.append(participant.summoner_spell_d.name)
        if participant.summoner_spell_f is not None:
            bss.append(participant.summoner_spell_f.name)
        # champion names
        blueteamchamps.append(participant.champion.name)
    # everything above, except for red team
    for participant in match.red_team.participants:
        rcs = rcs + participant.stats.minion_kills + participant.stats.monster_kills
        rkda = rkda + participant.stats.kda
        rcc = rcc + participant.stats.crowd_control_dealt
        rspree = rspree + participant.stats.killing_sprees
        rgold = rgold + participant.stats.gold_earned
        rdmg = rdmg + participant.stats.damage_dealt_to_champions
        if participant.summoner_spell_d is not None:
            rss.append(participant.summoner_spell_d.name)
        if participant.summoner_spell_f is not None:
            rss.append(participant.summoner_spell_f.name)
        redteamchamps.append(participant.champion.name)
    # difference in team creep score
    diffcs.append(bcs-rcs)
    # difference in team kda
    diffkda.append(bkda-rkda)
    # difference in team crowd control dealt
    diffcc.append(bcc-rcc)
    # difference in team number of killing sprees
    diffspree.append(bspree-rspree)
    # difference in team gold earned
    diffgold.append(bgold-rgold)
    # difference in team damage dealt to champions
    diffdmg.append(bdmg-rdmg)
    # difference in number of teleports
    difftp.append(bss.count('Teleport')-rss.count('Teleport'))
    
    # comparing champion categories on each side - tanks/non-tanks are binaries and ranged/melee are binaries, so we will 
    # only find differences in tanks and ranged, which means the rest of the team can be categorized as "non-tanks" and "melee"
    
    # blue team tank
    bluetanks = 0
    for champ in blueteamchamps:
        if ra.get_champion_by_name(champ).info.defense >= 7:
            bluetanks = bluetanks + 1
    # red team tank
    redtanks = 0
    for champ in redteamchamps:
        if ra.get_champion_by_name(champ).info.defense >= 7:
            redtanks = redtanks + 1
    # diff of number of tanks
    difftank.append(bluetanks-redtanks)

    # blue ranged champs
    bluerange = 0
    for champ in blueteamchamps:
        if ra.get_champion_by_name(champ).stats.attack_range > 200 or champ == 'Jayce' or champ == 'Kayle':
                bluerange = bluerange + 1
    # red ranged champs
    redrange = 0
    for champ in redteamchamps:
        if ra.get_champion_by_name(champ).stats.attack_range > 200 or champ == 'Jayce' or champ == 'Kayle':
                redrange = redrange + 1
    # diff of number of ranged champions
    diffrange.append(bluerange - redrange)
# Out:
# Processing match 1364966345
# Processing match 1365000117
# Processing match 1365001477
# Processing match 1365005581
# Processing match 1365190124
# Processing match 1365198605
# Processing match 1365203523
# Processing match 1365209089
# Processing match 1365218072
# Processing match 1365285451
# Processing match 1365302794
# Processing match 1365309714
# Processing match 1365312773
# Processing match 1365313183
# Processing match 1365338247
# Processing match 1365394610
# Processing match 1365408640
# Processing match 1365427812
# Processing match 1365460378
# Processing match 1365473036
# Processing match 1365483205
# Processing match 1365494761
# Processing match 1365495923
# Processing match 1365498486
# Processing match 1365758207
# Processing match 1365795032
# Processing match 1365820876
# Processing match 1365839894
# Processing match 1365874263
# Processing match 1366020180
# Processing match 1366077082
# Processing match 1366106882
# Processing match 1366149750
# Processing match 1366175749
# Processing match 1366195007
# Processing match 1366241290
# Processing match 1366346092
# Processing match 1366389722
# Processing match 1366405212
# Processing match 1366470891
# Processing match 1366567221
# Processing match 1366578170
# Processing match 1366603201
# Processing match 1366755104
# Processing match 1367189927
# Processing match 1367454988
# Processing match 1367502738
# Processing match 1367542357
# Processing match 1367572879
# Processing match 1367609971
# Processing match 1367613787
# Processing match 1367659449
# Processing match 1367664486
# Processing match 1367666324
# Processing match 1367761922
# Processing match 1367802969
# Processing match 1367912388
# Processing match 1367917954
# Processing match 1368061669
# Processing match 1368081038
# Processing match 1368113187
# Processing match 1368151097
# Processing match 1368161503
# Processing match 1368255832
# Processing match 1368320851
# Processing match 1368353242
# Processing match 1368376882
# Processing match 1368382443
# Processing match 1368422449
# Processing match 1368449795
# Processing match 1368520165
# Processing match 1368614655
# Processing match 1369113980
# Processing match 1369160008
# Processing match 1369164361
# Processing match 1369682208
# Processing match 1369722583
# Processing match 1369800639
# Processing match 1369820888
# Processing match 1370036985
# Processing match 1370054567
# Processing match 1370067184
# Processing match 1370068083
# Processing match 1370097920
# Processing match 1370173217
# Processing match 1370315769
# Processing match 1370316908
# Processing match 1370431586
# Processing match 1370562570
# Processing match 1370590003
# Processing match 1370598793
# Processing match 1370599994
# Processing match 1370609965
# Processing match 1370618343
# Processing match 1370624018
# Processing match 1370631688
# Processing match 1370644845
# Processing match 1370666666
# Processing match 1370677680
# Processing match 1370699634
# Processing match 1370709999
# Processing match 1370734331
# Processing match 1370756593
# Processing match 1370769227
# Processing match 1370777472
# Processing match 1370778895
# Processing match 1370788867
# Processing match 1370836570
# Processing match 1370881583
# Processing match 1370919282
# Processing match 1371198718
# Processing match 1371329890
# Processing match 1371353852
# Processing match 1371364959
# Processing match 1371381370
# Processing match 1371386580
# Processing match 1371614594
# Processing match 1371627816
# Processing match 1371662289
# Processing match 1371668079
# Processing match 1371671539
# Processing match 1371686262
# Processing match 1371729401
# Processing match 1371734134
# Processing match 1371736685
# Processing match 1371776798
# Processing match 1371848385
# Processing match 1371851182
# Processing match 1371933730
# Processing match 1372092851
# Processing match 1372121814
# Processing match 1372131335
# Processing match 1372167145
# Processing match 1372204774
# Processing match 1372253416
# Processing match 1372415415
# Processing match 1372419202
# Processing match 1372428216
# Processing match 1372487622
# Processing match 1372571803
# Processing match 1372575698
# Processing match 1372660103
# Processing match 1372665583
# Processing match 1372689910
# Processing match 1372694780
# Processing match 1372801724
# Processing match 1372812192
# Processing match 1372816117
# Processing match 1372893772
# Processing match 1372899591
# Processing match 1372926045
# Processing match 1372968542
# Processing match 1372970018
# Processing match 1372979330
# Processing match 1372992582
# Processing match 1372995041
# Processing match 1373005870
# Processing match 1373024217
# Processing match 1373050367
# Processing match 1373051009
# Processing match 1373067817
# Processing match 1373071713
# Processing match 1373099938
# Processing match 1373123613
# Processing match 1373142523
# Processing match 1373181594
# Processing match 1373188648
# Processing match 1373218253
# Processing match 1373237946
# Processing match 1373248725
# Processing match 1373524389
# Processing match 1373604948
# Processing match 1373606727
# Processing match 1373733404
# Processing match 1373739775
# Processing match 1373770914
# Processing match 1373781973
# Processing match 1373786899
# Processing match 1373802632
# Processing match 1373814151
# Processing match 1373842817
# Processing match 1373858430
# Processing match 1373872791
# Processing match 1373891408
# Processing match 1373896194
# Processing match 1373920361
# Processing match 1373927417
# Processing match 1373948622
# Processing match 1373967458
# Processing match 1373991695
# Processing match 1374031523
# Processing match 1374288790
# Processing match 1374297553
# Processing match 1374343898
# Processing match 1374569815
# Processing match 1374571405
# Processing match 1374573570
# Processing match 1374610913
# Processing match 1374617224
# Processing match 1374628246
# Processing match 1374643620
# Processing match 1374648394
# Processing match 1374653591
# Processing match 1374666165
# Processing match 1374676666
# Processing match 1374684333
# Processing match 1374694809
# Processing match 1374694864
# Processing match 1374722650
# Processing match 1374763312
# Processing match 1374792504
# Processing match 1374811897
# Processing match 1374823296
# Processing match 1374876004
# Processing match 1374941581
# Processing match 1374963055
# Processing match 1374979603
# Processing match 1375193996
# Processing match 1375349584
# Processing match 1375361274
# Processing match 1375388193
# Processing match 1375465200
# Processing match 1375469059
# Processing match 1375470854
# Processing match 1375512449
# Processing match 1375518237
# Processing match 1375542107
# Processing match 1375554921
# Processing match 1375557141
# Processing match 1375578681
# Processing match 1375656407
# Processing match 1375684627
# Processing match 1375720979
# Processing match 1375748248
# Processing match 1375817055
# Processing match 1376132220
# Processing match 1376189571
# Processing match 1376226444
# Processing match 1376264132
# Processing match 1376301070
# Processing match 1376348925
# Processing match 1376371276
# Processing match 1376388209
# Processing match 1376412968
# Processing match 1376428778
# Processing match 1376433676
# Processing match 1376434169
# Processing match 1376443496
# Processing match 1376458053
# Processing match 1376481879
# Processing match 1376490915
# Processing match 1376505756
# Processing match 1376541337
# Processing match 1376549463
# Processing match 1376574726
# Processing match 1376579703
# Processing match 1376595671
# Processing match 1376640190
# Processing match 1376665648
# Processing match 1376739245
# Processing match 1376742525
# Processing match 1376756176
# Processing match 1376846451
# Processing match 1376849198
# Processing match 1376904261
# Processing match 1376970724
# Processing match 1376974858
# Processing match 1377020589
# Processing match 1377076971
# Processing match 1377080907
# Processing match 1377102751
# Processing match 1377108822
# Processing match 1377133847
# Processing match 1377154061
# Processing match 1377158101
# Processing match 1377174132
# Processing match 1377220028
# Processing match 1377240435
# Processing match 1377253003
# Processing match 1377257866
# Processing match 1377296747
# Processing match 1377316351
# Processing match 1377334253
# Processing match 1377345611
# Processing match 1377363863
# Processing match 1377390814
# Processing match 1377424248
# Processing match 1377427575
# Processing match 1377459335
# Processing match 1377464114
# Processing match 1377645936
# Processing match 1377653488
# Processing match 1377728749
# Processing match 1377806972
# Processing match 1377842057
# Processing match 1377873191
# Processing match 1377891625
# Processing match 1377925813
# Processing match 1377961561
# Processing match 1377975562
# Processing match 1378007871
# Processing match 1378010726
# Processing match 1378050853
# Processing match 1378051388
# Processing match 1378056515
# Processing match 1378086455
# Processing match 1378103265
# Processing match 1378118287
# Processing match 1378119464
# Processing match 1378130343
# Processing match 1378134614
# Processing match 1378160703
# Processing match 1378529583
# Processing match 1378599744
# Processing match 1378613929
# Processing match 1378701347
# Processing match 1378749787
# Processing match 1378772954
# Processing match 1378789698
# Processing match 1378790082
# Processing match 1378825254
# Processing match 1378885146
# Processing match 1378947135
# Processing match 1379027683
# Processing match 1379074825
# Processing match 1379174590
# Processing match 1379240230
# Processing match 1379262563
# Processing match 1379266997
# Processing match 1379353643
# Processing match 1379371838
# Processing match 1379381196
# Processing match 1379403897
# Processing match 1379408935
# Processing match 1379615083
# Processing match 1379651949
# Processing match 1379685166
# Processing match 1379700228
# Processing match 1379707626
# Processing match 1379793729
# Processing match 1379796949
# Processing match 1379953024
# Processing match 1379984491
# Processing match 1379986849
# Processing match 1380048686
# Processing match 1380110077
# Processing match 1380126527
# Processing match 1380126680
# Processing match 1380174448
# Processing match 1380226925
# Processing match 1380266275
# Processing match 1380272743
# Processing match 1380294900
# Processing match 1380297928
# Processing match 1380319322
# Processing match 1380333876
# Processing match 1380391433
# Processing match 1380409409
# Processing match 1380410449
# Processing match 1380451417
# Processing match 1380461630
# Processing match 1380764337
# Processing match 1380846824
# Processing match 1380880431
# Processing match 1380905747
# Processing match 1380951684
# Processing match 1381015211
# Processing match 1381025984
# Processing match 1381034406
# Processing match 1381065113
# Processing match 1381072458
# Processing match 1381095010
# Processing match 1381140339
# Processing match 1381151578
# Processing match 1381191531
# Processing match 1381276600
# Processing match 1381316473
# Processing match 1381336080
# Processing match 1381354648
# Processing match 1381394383
# Processing match 1381460351
# Processing match 1381460490
# Processing match 1381578080
# Processing match 1381580635
# Processing match 1381632695
# Processing match 1381917626
# Processing match 1381955326
# Processing match 1381968773
# Processing match 1381970543
# Processing match 1382136871
# Processing match 1382262261
# Processing match 1382297964
# Processing match 1382384582
# Processing match 1382457352
# Processing match 1382509849
# Processing match 1382537856
# Processing match 1382562079
# Processing match 1382581132
# Processing match 1382617465
# Processing match 1382624126
# Processing match 1382649670
# Processing match 1382662135
# Processing match 1382671831
# Processing match 1382722717
# Processing match 1382737285
# Processing match 1383070735
# Processing match 1383081618
# Processing match 1383094268
# Processing match 1383185276
# Processing match 1383231362
# Processing match 1383239591
# Processing match 1383279504
# Processing match 1383377145
# Processing match 1383440277
# Processing match 1383445455
# Processing match 1383469455
# Processing match 1383556221
# Processing match 1383663456
# Processing match 1383735484
# Processing match 1383839153
# Processing match 1383883944
# Processing match 1383893444
# Processing match 1383898311
# Processing match 1383921484
# Processing match 1383945854
# Processing match 1383960267
# Processing match 1383966423
# Processing match 1383993905
# Processing match 1383998981
# Processing match 1384002565
# Processing match 1384027960
# Processing match 1384034495
# Processing match 1384060284
# Processing match 1384066496
# Processing match 1384089191
# Processing match 1384098027
# Processing match 1384102034
# Processing match 1384102662
# Processing match 1384196380
# Processing match 1384202782
# Processing match 1384610788
# Processing match 1384621890
# Processing match 1384884326
# Processing match 1385068735
# Processing match 1385114674
# Processing match 1385128558
# Processing match 1385143753
# Processing match 1385150713
# Processing match 1385156206
# Processing match 1385241865
# Processing match 1385272802
# Processing match 1385282270
# Processing match 1385302886
# Processing match 1385332740
# Processing match 1385342637
# Processing match 1385383637
# Processing match 1385387809
# Processing match 1385442031
# Processing match 1385476915
# Processing match 1385560207
# Processing match 1385600388
# Processing match 1385603457
# Processing match 1385632467
# Processing match 1385639237
# Processing match 1385666706
# Processing match 1385703203
# Processing match 1385752608
# Processing match 1385754612
# Processing match 1385758672
# Processing match 1385812623
# Processing match 1386174701
# Processing match 1386284944
# Processing match 1386298669
# Processing match 1386460252
# Processing match 1386466738
# Processing match 1386473447
# Processing match 1386514895
# Processing match 1386531275
# Processing match 1386561550
# Processing match 1386605283
# Processing match 1386693520
# Processing match 1386701838
# Processing match 1386723232
# Processing match 1386736855
# Processing match 1386740720
# Processing match 1386769593
# Processing match 1386770879
# Processing match 1386797502
# Processing match 1386802393
# Processing match 1386847661
# Processing match 1386908309
# Processing match 1386958097
# Processing match 1387054274
# Processing match 1387096148
# Processing match 1387264921
# Processing match 1387313530
# Processing match 1387322027
# Processing match 1387355732
# Processing match 1387374909
# Processing match 1387399255
# Processing match 1387441597
# Processing match 1387454889
# Processing match 1387493624
# Processing match 1387640673
# Processing match 1387789335
# Processing match 1387944388
# Processing match 1388052579
# Processing match 1388066638
# Processing match 1388122077
# Processing match 1388186463
# Processing match 1388221011
# Processing match 1388570612
# Processing match 1388675640
# Processing match 1388728789
# Processing match 1388839799
# Processing match 1388891412
# Processing match 1389321620
# Processing match 1389329673
# Processing match 1389353422
# Processing match 1389468914
# Processing match 1389501463
# Processing match 1389510265
# Processing match 1389522520
# Processing match 1389743858
# Processing match 1390080175
# Processing match 1390101353
# Processing match 1390115080
# Processing match 1390144028
# Processing match 1390353991
# Processing match 1390387043
# Processing match 1390406641
# Processing match 1390483636
# Processing match 1390558586
# Processing match 1390690204
# Processing match 1391255555
# Processing match 1391270625
# Processing match 1391276781
# Processing match 1391304079
# Processing match 1391308481
# Processing match 1391349129
# Processing match 1391419691
# Processing match 1391448546
# Processing match 1391528071
# Processing match 1391941647
# Processing match 1392020935
# Processing match 1392033361
# Processing match 1392036265
# Processing match 1392100750
# Processing match 1392112066
# Processing match 1392115268
# Processing match 1392119179
# Processing match 1392163923
# Processing match 1392255522
# Processing match 1392318017
# Processing match 1392354917
# Processing match 1392368861
# Processing match 1392512414
# Processing match 1392676703
# Processing match 1392681208
# Processing match 1392693305
# Processing match 1392781416
# Processing match 1392829976
# Processing match 1392898033
# Processing match 1392941506
# Processing match 1392961254
# Processing match 1393057514
# Processing match 1393066375
# Processing match 1393094103
# Processing match 1393098548
# Processing match 1393180265
# Processing match 1393200633
# Processing match 1393469709
# Processing match 1393512011
# Processing match 1393526655
# Processing match 1393563143
# Processing match 1393596347
# Processing match 1393651001
# Processing match 1393679203
# Processing match 1393697045
# Processing match 1393740612
# Processing match 1393764261
# Processing match 1393766791
# Processing match 1393894022
# Processing match 1393925870
# Processing match 1393958701
# Processing match 1393981386
# Processing match 1394015355
# Processing match 1394026423
# Processing match 1394031776
# Processing match 1394037237
# Processing match 1394073644
# Processing match 1394240497
# Processing match 1394245766
# Processing match 1394381492
# Processing match 1394409159
# Processing match 1394470770
# Processing match 1394485271
# Processing match 1394528181
# Processing match 1394551804
# Processing match 1394580713
# Processing match 1394598208
# Processing match 1394678730
# Processing match 1394706437
# Processing match 1394708001
# Processing match 1394773649
# Processing match 1394814023
# Processing match 1394866521
# Processing match 1395002587
# Processing match 1395108836
# Processing match 1395162177
# Processing match 1395246369
# Processing match 1395252554
# Processing match 1395293741
# Processing match 1395295963
# Processing match 1395326240
# Processing match 1395348425
# Processing match 1395350971
# Processing match 1395353549
# Processing match 1395368981
# Processing match 1395369318
# Processing match 1395399899
# Processing match 1395402429
# Processing match 1395417568
# Processing match 1395437781
# Processing match 1395444435
# Processing match 1395486779
# Processing match 1395516147
# Processing match 1395520214
# Processing match 1395562133
# Processing match 1395563925
# Processing match 1395578188
# Processing match 1395585396
# Processing match 1395587089
# Processing match 1395598371
# Processing match 1395624280
# Processing match 1395631574
# Processing match 1395641337
# Processing match 1395642317
# Processing match 1395660974
# Processing match 1395671950
# Processing match 1395674658
# Processing match 1395690281
# Processing match 1395692872
# Processing match 1396147303
# Processing match 1396150118
# Processing match 1396215010
# Processing match 1396218858
# Processing match 1396263520
# Processing match 1396274316
# Processing match 1396316429
# Processing match 1396332791
# Processing match 1396364488
# Processing match 1396382228
# Processing match 1396386666
# Processing match 1396388733
# Processing match 1396417682
# Processing match 1396426977
# Processing match 1396468066
# Processing match 1396484961
# Processing match 1396504852
# Processing match 1396517797
# Processing match 1396568748
# Processing match 1396569964
# Processing match 1396624444
# Processing match 1396636597
# Processing match 1396677024
# Processing match 1396696081
# Processing match 1396725514
# Processing match 1396776236
# Processing match 1396824969
# Processing match 1396831918
# Processing match 1396833806
# Processing match 1396905520
# Processing match 1396934200
# Processing match 1396934897
# Processing match 1397014578
# Processing match 1397127841
# Processing match 1397245966
# Processing match 1397269294
# Processing match 1397305565
# Processing match 1397319500
# Processing match 1397355964
# Processing match 1397374941
# Processing match 1397392791
# Processing match 1397407880
# Processing match 1397441488
# Processing match 1397442165
# Processing match 1397450493
# Processing match 1397480438
# Processing match 1397501514
# Processing match 1397520702
# Processing match 1397643130
# Processing match 1397762687
# Processing match 1397814215
# Processing match 1397922039
# Processing match 1397937463
# Processing match 1397947281
# Processing match 1397983622
# Processing match 1398007340
# Processing match 1398016978
# Processing match 1398029831
# Processing match 1398040966
# Processing match 1398048413
# Processing match 1398051738
# Processing match 1398058040
# Processing match 1398075630
# Processing match 1398093221
# Processing match 1398095633
# Processing match 1398104373
# Processing match 1398109258
# Processing match 1398120545
# Processing match 1398195123
# Processing match 1398224278
# Processing match 1398232317
# Processing match 1398234165
# Processing match 1398237207
# Processing match 1398248885
# Processing match 1398255660
# Processing match 1398260617
# Processing match 1398279268
# Processing match 1398282493
# Processing match 1398352566
# Processing match 1398375054
# Processing match 1398402197
# Processing match 1398404700
# Processing match 1398406202
# Processing match 1398409604
# Processing match 1398556692
# Processing match 1398566030
# Processing match 1398684352
# Processing match 1398688557
# Processing match 1398711122
# Processing match 1398718161
# Processing match 1398792584
# Processing match 1398827483
# Processing match 1398902191
# Processing match 1398978814
# Processing match 1398990825
# Processing match 1399018547
# Processing match 1399021706
# Processing match 1399038048
# Processing match 1399068222
# Processing match 1399071193
# Processing match 1399083386
# Processing match 1399092282
# Processing match 1399111504
# Processing match 1399122947
# Processing match 1399157592
# Processing match 1399160535
# Processing match 1399375532
# Processing match 1399474048
# Processing match 1399508281
# Processing match 1399594939
# Processing match 1399720427
# Processing match 1399765088
# Processing match 1399786736
# Processing match 1399809311
# Processing match 1399819674
# Processing match 1399844355
# Processing match 1399855907
# Processing match 1399888603
# Processing match 1399890571
# Processing match 1399891409
# Processing match 1399903625
# Processing match 1399928594
# Processing match 1399973138
# Processing match 1400040032
# Processing match 1400086993
# Processing match 1400137346
# Processing match 1400201738
# Processing match 1400219353
# Processing match 1400226147
# Processing match 1400323292
# Processing match 1400334991
# Processing match 1400380768
# Processing match 1400685500
# Processing match 1400689960
# Processing match 1400694715
# Processing match 1400695833
# Processing match 1400718351
# Processing match 1400783690
# Processing match 1400788162
# Processing match 1400804127
# Processing match 1400816949
# Processing match 1400854081
# Processing match 1400888576
# Processing match 1400924287
# Processing match 1400934994
# Processing match 1400936313
# Processing match 1400973970
# Processing match 1401009369
# Processing match 1401059345
# Processing match 1401101115
# Processing match 1401151687
# Processing match 1401209617
# Processing match 1401284325
# Processing match 1401302480
# Processing match 1401350736
# Processing match 1401396619
# Processing match 1401417900
# Processing match 1401426631
# Processing match 1401467585
# Processing match 1401506332
# Processing match 1401533124
# Processing match 1401574231
# Processing match 1401597239
# Processing match 1401696392
# Processing match 1401698633
# Processing match 1401737489
# Processing match 1401995274
# Processing match 1402003766
# Processing match 1402019018
# Processing match 1402063933
# Processing match 1402069219
# Processing match 1402103086
# Processing match 1402114926
# Processing match 1402157171
# Processing match 1402170248
# Processing match 1402189569
# Processing match 1402224838
# Processing match 1402280356
# Processing match 1402484790
# Processing match 1402539256
# Processing match 1402655516
# Processing match 1402656009
# Processing match 1402737661
# Processing match 1402774069
# Processing match 1402874089
# Processing match 1402914458
# Processing match 1402938314
# Processing match 1403041219
# Processing match 1403063248
# Processing match 1403099459
# Processing match 1403264374
# Processing match 1403284355
# Processing match 1403292472
# Processing match 1403318797
# Processing match 1403354286
# Processing match 1403402329
# Processing match 1403441359
# Processing match 1403459127
# Processing match 1403474949
# Processing match 1403514103
# Processing match 1403931225
# Processing match 1404209924
# Processing match 1404238905
# Processing match 1404282498
# Processing match 1404287709
# Processing match 1404317689
# Processing match 1404333592
# Processing match 1404352314
# Processing match 1404355039
# Processing match 1404357214
# Processing match 1404528962
# Processing match 1404536636
# Processing match 1404548197
# Processing match 1404652292
# Processing match 1404689488
# Processing match 1404721420
# Processing match 1404749607
# Processing match 1404796654
# Processing match 1404837333
# Processing match 1404852497
# Processing match 1404933179
# Processing match 1404958140
# Processing match 1405001858
# Processing match 1405033846
# Processing match 1405050974
# Processing match 1405069573
# Processing match 1405204847
# Processing match 1405254007
# Processing match 1405258805
# Processing match 1405287318
# Processing match 1405345757
# Processing match 1405369841
# Processing match 1405390932
# Processing match 1405421641
# Processing match 1405427288
# Processing match 1405447382
# Processing match 1405459653
# Processing match 1405471324
# Processing match 1405524447
# Processing match 1405578273
# Processing match 1405707700
# Processing match 1405813402
# Processing match 1405909389
# Processing match 1405938558
# Processing match 1405976740
# Processing match 1405996874
# Processing match 1406056295
# Processing match 1406129980
# Processing match 1406165765
# Processing match 1406206081
# Processing match 1406212509
# Processing match 1406316330
# Processing match 1406330072
# Processing match 1406338469
# Processing match 1406408773
# Processing match 1406482813
# Processing match 1406523409
# Processing match 1406631462
# Processing match 1406722132
# Processing match 1406782386
# Processing match 1406824601
# Processing match 1406828223
# Processing match 1407044075
# Processing match 1407215965
# Processing match 1407231856
# Processing match 1407246890
# Processing match 1407290575
# Processing match 1407311131
# Processing match 1407318995
# Processing match 1407347839
# Processing match 1407376116
# Processing match 1407377095
# Processing match 1407416712
# Processing match 1407424196
# Processing match 1407431505
# Processing match 1407453468
# Processing match 1407510706
# Processing match 1407570309
# Processing match 1407610455
# Processing match 1407623465
# Processing match 1407647423
# Processing match 1407704182
# Processing match 1407802334
# Processing match 1407874881
# Processing match 1407991111
# Processing match 1407993947
# Processing match 1408020513
# Processing match 1408026649
# Processing match 1408031378
# Processing match 1408064716
# Processing match 1408068272
# Processing match 1408070470
# Processing match 1408091270
# Processing match 1408094047
# Processing match 1408166369
# Processing match 1408177198
# Processing match 1408188773
# Processing match 1408203903
# Processing match 1408220997
# Processing match 1408225882
# Processing match 1408262282
# Processing match 1408307800
# Processing match 1408309653
# Processing match 1408311819
# Processing match 1408339312
# Processing match 1408382440
# Processing match 1408388343
# Processing match 1408404075
# Processing match 1408463666
# Processing match 1408467263
# Processing match 1408477756
# Processing match 1408497924
# Processing match 1408581028
# Processing match 1408583465
# Processing match 1408618171
# Processing match 1408907480
# Processing match 1408973544
# Processing match 1409007750
# Processing match 1409050998
# Processing match 1409061258
# Processing match 1409077095
# Processing match 1409083980
# Processing match 1409087528
# Processing match 1409089558
# Processing match 1409097638
# Processing match 1409108483
# Processing match 1409121820
# Processing match 1409124127
# Processing match 1409128489
# Processing match 1409135751
# Processing match 1409164545
# Processing match 1409170120
# Processing match 1409173340
# Processing match 1409178313
# Processing match 1409192347
# Processing match 1409203902
# Processing match 1409216308
# Processing match 1409636675
# Processing match 1409693904
# Processing match 1409734879
# Processing match 1409792605
# Processing match 1409798191
# Processing match 1409830483
# Processing match 1409934919
# Processing match 1409962189
# Processing match 1409977977
# Processing match 1409979749
# Processing match 1410027817
# Processing match 1410032934
# Processing match 1410057766
# Processing match 1410121902
# Processing match 1410173685
# Processing match 1410200865
# Processing match 1410218702
# Processing match 1410293636
# Processing match 1410299300
# Processing match 1410353913
# Processing match 1410358626
# Processing match 1410729685
# Processing match 1410735549
# Processing match 1410778198
# Processing match 1410791336
# Processing match 1410851110
# Processing match 1410885654
# Processing match 1410898808
# Processing match 1410985240
# Processing match 1411045016
# Processing match 1411049401
# Processing match 1411096109
# Processing match 1411272745
# Processing match 1411376695
# Processing match 1411378345
# Processing match 1411437835
# Processing match 1411503446
# Processing match 1411505138
# Processing match 1411537802
# Processing match 1411568331
# Processing match 1411570362
# Processing match 1411582345
# Processing match 1411582547
# Processing match 1411596690
# Processing match 1411622973
# Processing match 1411627496
# Processing match 1411636628
# Processing match 1411645430
# Processing match 1411671852
# Processing match 1411674328
# Processing match 1411686573
# Processing match 1411764634
# Processing match 1411797727
# Processing match 1411809074
# Processing match 1411840993
# Processing match 1411860655
# Processing match 1411863686
# Processing match 1411906053
# Processing match 1411914219
# Processing match 1411987528
# Processing match 1412032765
# Processing match 1412147094
# Processing match 1412317867
# Processing match 1412347541
# Processing match 1412414637
# Processing match 1412419375
# Processing match 1412455984
# Processing match 1412636545
# Processing match 1412678539
# Processing match 1412715695
# Processing match 1412745949
# Processing match 1412746615
# Processing match 1412786234
# Processing match 1412805017
# Processing match 1412808565
# Processing match 1413175469
# Processing match 1413200518
# Processing match 1413229989
# Processing match 1413290692
# Processing match 1413305115
# Processing match 1413334775
# Processing match 1413416789
# Processing match 1413468428
# Processing match 1413514556
# Processing match 1413655140
# Processing match 1413792294
# Processing match 1413861994
# Processing match 1413939344
# Processing match 1413944133
# Processing match 1413988727
# Processing match 1414001452
# Processing match 1414006022
# Processing match 1414038863
# Processing match 1414041567
# Processing match 1414059611
# Processing match 1414075200
# Processing match 1414087336
# Processing match 1414106762
# Processing match 1414112356
# Processing match 1414119217
# Processing match 1414123438
# Processing match 1414142735
# Processing match 1414152946
# Processing match 1414160739
# Processing match 1414163112
# Processing match 1414221335
# Processing match 1414237924
# Processing match 1414263486
# Processing match 1414415714
# Processing match 1414602431
# Processing match 1414618118
# Processing match 1414744094
# Processing match 1414815001
# Processing match 1414852717
# Processing match 1414860147
# Processing match 1414888839
# Processing match 1414945456
# Processing match 1414992846
# Processing match 1415053648
# Processing match 1415104061
# Processing match 1415153711
# Processing match 1415203917
# Processing match 1415280519
# Processing match 1415573126
# Processing match 1415588943
# Processing match 1415593071
# Processing match 1415608146
# Processing match 1415612474
# Processing match 1415613215
# Processing match 1415642457
# Processing match 1415658789
# Processing match 1415697607
# Processing match 1415722130
# Processing match 1415734441
# Processing match 1415735842
# Processing match 1415740977
# Processing match 1415751376
# Processing match 1415765583
# Processing match 1415772289
# Processing match 1415778203
# Processing match 1415810239
# Processing match 1415842144
# Processing match 1415861666
# Processing match 1415885683
# Processing match 1415934122
# Processing match 1416042161
# Processing match 1416094307
# Processing match 1416102459
# Processing match 1416224591
# Processing match 1416240873
# Processing match 1416287811
# Processing match 1416292386
# Processing match 1416399071
# Processing match 1416412418
# Processing match 1416422923
# Processing match 1416443574
# Processing match 1416459192
# Processing match 1416516518
# Processing match 1416557364
# Processing match 1416571160
# Processing match 1416799593
# Processing match 1416819451
# Processing match 1416842497
# Processing match 1416857563
# Processing match 1416873856
# Processing match 1416878414
# Processing match 1416893960
# Processing match 1416942511
# Processing match 1416950160
# Processing match 1416964841
# Processing match 1416965774
# Processing match 1417013856
# Processing match 1417131740
# Processing match 1417204671
# Processing match 1417217162
# Processing match 1417255797
# Processing match 1417370478
# Processing match 1417375623
# Processing match 1417440617
# Processing match 1417469683
# Processing match 1417470901
# Processing match 1417476234
# Processing match 1417537869
# Processing match 1417599992
# Processing match 1417772709
# Processing match 1417810044
# Processing match 1417829203
# Processing match 1417830586
# Processing match 1417838829
# Processing match 1417868846
# Processing match 1417986742
# Processing match 1418038544
# Processing match 1418072865
# Processing match 1418222591
# Processing match 1418224828
# Processing match 1418247352
# Processing match 1418297219
# Processing match 1418304014
# Processing match 1418352396
# Processing match 1418358785
# Processing match 1418405943
# Processing match 1418458731
# Processing match 1418549674
# Processing match 1418591511
# Processing match 1418652414
# Processing match 1418656010
# Processing match 1418690690
# Processing match 1418696635
# Processing match 1418705180
# Processing match 1418717606
# Processing match 1418744357
# Processing match 1418756716
# Processing match 1418758892
# Processing match 1418767893
# Processing match 1418778326
# Processing match 1418788705
# Processing match 1418891023
# Processing match 1419043303
# Processing match 1419138945
# Processing match 1419147988
# Processing match 1419176579
# Processing match 1419198946
# Processing match 1419203369
# Processing match 1419229463
# Processing match 1419265244
# Processing match 1419273815
# Processing match 1419292920
# Processing match 1419305660
# Processing match 1419364363
# Processing match 1419421102
# Processing match 1419428993
# Processing match 1419500582
# Processing match 1419510746
# Processing match 1419518206
# Processing match 1419558521
# Processing match 1419717648
# Processing match 1419749928
# Processing match 1419767298
# Processing match 1419844697
# Processing match 1419903598
# Processing match 1419908334
# Processing match 1419978695
# Processing match 1419980572
# Processing match 1419982837
# Processing match 1419998737
# Processing match 1420061945
# Processing match 1420065395
# Processing match 1420092167
# Processing match 1420110308
# Processing match 1420114903
# Processing match 1420143672
# Processing match 1420164140
# Processing match 1420167606
# Processing match 1420194806
# Processing match 1420235751
# Processing match 1420241662
# Processing match 1420258756
# Processing match 1420258800
# Processing match 1420260823
# Processing match 1420265265
# Processing match 1420408337
# Processing match 1420587515
# Processing match 1420855266
# Processing match 1420929039
# Processing match 1420931736
# Processing match 1420936353
# Processing match 1420974664
# Processing match 1420997902
# Processing match 1421016501
# Processing match 1421020415
# Processing match 1421025494
# Processing match 1421035058
# Processing match 1421066852
# Processing match 1421069864
# Processing match 1421071832
# Processing match 1421075291
# Processing match 1421099747
# Processing match 1421121389
# Processing match 1421122291
# Processing match 1421145014
# Processing match 1421157899
# Processing match 1421161923
# Processing match 1421179973
# Processing match 1421225973
# Processing match 1421247575
# Processing match 1421293093
# Processing match 1421322466
# Processing match 1421336034
# Processing match 1421431656
# Processing match 1421491679
# Processing match 1421561951
# Processing match 1421734264
# Processing match 1421772329
# Processing match 1421778126
# Processing match 1421868881
# Processing match 1421964274
# Processing match 1422016588
# Processing match 1422031714
# Processing match 1422039976
# Processing match 1422055306
# Processing match 1422093270
# Processing match 1422098045
# Processing match 1422114663
# Processing match 1422115933
# Processing match 1422175106
# Processing match 1422183555
# Processing match 1422197346
# Processing match 1422211080
# Processing match 1422226792
# Processing match 1422240532
# Processing match 1422244155
# Processing match 1422267317
# Processing match 1422271080
# Processing match 1422291741
# Processing match 1422295088
# Processing match 1422297983
# Processing match 1422395209
# Processing match 1422426438
# Processing match 1422458305
# Processing match 1422499748
# Processing match 1422575035
# Processing match 1422639254
# Processing match 1422644405
# Processing match 1422693796
# Processing match 1422695042
# Processing match 1422697432
# Processing match 1422743451
# Processing match 1422768438
# Processing match 1422782269
# Processing match 1422824657
# Processing match 1422858407
# Processing match 1422913810
# Processing match 1422964622
# Processing match 1423017744
# Processing match 1423092836
# Processing match 1423111636
# Processing match 1423149741
# Processing match 1423161308
# Processing match 1423194544
# Processing match 1423198787
# Processing match 1423216870
# Processing match 1423261933
# Processing match 1423314036
# Processing match 1423365331
# Processing match 1423368410
# Processing match 1423390034
# Processing match 1423480500
# Processing match 1423483381
# Processing match 1423485920
# Processing match 1423486840
# Processing match 1423770592
# Processing match 1423829902
# Processing match 1423910529
# Processing match 1423924789
# Processing match 1423931901
# Processing match 1423948197
# Processing match 1423975096
# Processing match 1424001658
# Processing match 1424036086
# Processing match 1424077430
# Processing match 1424112403
# Processing match 1424127642
# Processing match 1424175082
# Processing match 1424216813
# Processing match 1424274570
# Processing match 1424300718
# Processing match 1424828583
# Processing match 1424859170
# Processing match 1424872798
# Processing match 1424877999
# Processing match 1424879743
# Processing match 1424912754
# Processing match 1424977678
# Processing match 1425004189
# Processing match 1425036922
# Processing match 1425040208
# Processing match 1425060736
# Processing match 1425075081
# Processing match 1425083740
# Processing match 1425203489
# Processing match 1425393498
# Processing match 1425442619
# Processing match 1425463576
# Processing match 1425500816
# Processing match 1425519460
# Processing match 1425558272
# Processing match 1425655020
# Processing match 1425683307
# Processing match 1425752652
# Processing match 1425754846
# Processing match 1425842996
# Processing match 1425853095
# Processing match 1425853534
# Processing match 1425869105
# Processing match 1425887703
# Processing match 1425896113
# Processing match 1425899199
# Processing match 1425904901
# Processing match 1425908771
# Processing match 1425928984
# Processing match 1425941170
# Processing match 1425972770
# Processing match 1426062328
# Processing match 1426251102
# Processing match 1426264922
# Processing match 1426290064
# Processing match 1426304047
# Processing match 1426308903
# Processing match 1426311236
# Processing match 1426350348
# Processing match 1426369321
# Processing match 1426420729
# Processing match 1426422674
# Processing match 1426437647
# Processing match 1426451766
# Processing match 1426501752
# Processing match 1426520078
# Processing match 1426528778
# Processing match 1426534737
# Processing match 1426573250
# Processing match 1426589200
# Processing match 1426592295
# Processing match 1426641893
# Processing match 1426675206
# Processing match 1426690568
# Processing match 1426707230
# Processing match 1426761528
# Processing match 1426841009
# Processing match 1426861409
# Processing match 1426966383
# Processing match 1427040058
# Processing match 1427047174
# Processing match 1427127120
# Processing match 1427134951
# Processing match 1427165429
# Processing match 1427166619
# Processing match 1427189992
# Processing match 1427296102
# Processing match 1427301853
# Processing match 1427307159
# Processing match 1427308360
# Processing match 1427334288
# Processing match 1427339002
# Processing match 1427355388
# Processing match 1427366244
# Processing match 1427386551
# Processing match 1427402773
# Processing match 1427426986
# Processing match 1427443358
# Processing match 1427469345
# Processing match 1427476091
# Processing match 1427477689
# Processing match 1427484175
# Processing match 1427486453
# Processing match 1427505893
# Processing match 1427508472
# Processing match 1427519101
# Processing match 1427523805
# Processing match 1427529327
# Processing match 1427558224
# Processing match 1427567809
# Processing match 1427570217
# Processing match 1427583171
# Processing match 1427608051
# Processing match 1427727428
# Processing match 1427811750
# Processing match 1427844024
# Processing match 1427944911
# Processing match 1427985471
# Processing match 1428000297
# Processing match 1428022261
# Processing match 1428060564
# Processing match 1428078703
# Processing match 1428079417
# Processing match 1428115950
# Processing match 1428136471
# Processing match 1428150603
# Processing match 1428181400
# Processing match 1428199213
# Processing match 1428200518
# Processing match 1428204432
# Processing match 1428228488
# Processing match 1428269183
# Processing match 1428278519
# Processing match 1428280819
# Processing match 1428298956
# Processing match 1428319976
# Processing match 1428414043
# Processing match 1428425110
# Processing match 1428502369
# Processing match 1428504121
# Processing match 1428517853
# Processing match 1428712420
# Processing match 1428722712
# Processing match 1428788670
# Processing match 1428790204
# Processing match 1428843647
# Processing match 1428871682
# Processing match 1428886186
# Processing match 1428890804
# Processing match 1428911473
# Processing match 1428917729
# Processing match 1428929805
# Processing match 1428932533
# Processing match 1429060341
# Processing match 1429066681
# Processing match 1429078087
# Processing match 1429121745
# Processing match 1429130607
# Processing match 1429133875
# Processing match 1429162610
# Processing match 1429196532
# Processing match 1429210594
# Processing match 1429233883
# Processing match 1429258565
# Processing match 1429274124
# Processing match 1429301992
# Processing match 1429321837
# Processing match 1429322832
# Processing match 1429326075
# Processing match 1429327145
# Processing match 1429354811
# Processing match 1429361403
# Processing match 1429375976
# Processing match 1429377757
# Processing match 1429524039
# Processing match 1429665064
# Processing match 1429669927
# Processing match 1429677575
# Processing match 1429693155
# Processing match 1429696491
# Processing match 1429717760
# Processing match 1429761155
# Processing match 1429782837
# Processing match 1429812217
# Processing match 1429836923
# Processing match 1429851910
# Processing match 1429868913
# Processing match 1429879903
# Processing match 1429882351
# Processing match 1429915933
# Processing match 1429930651
# Processing match 1429947411
# Processing match 1429981839
# Processing match 1429992527
# Processing match 1430007020
# Processing match 1430027408
# Processing match 1430053737
# Processing match 1430093744
# Processing match 1430290901
# Processing match 1430402168
# Processing match 1430408993
# Processing match 1430470574
# Processing match 1430566589
# Processing match 1430574671
# Processing match 1430605179
# Processing match 1430606476
# Processing match 1430643108
# Processing match 1430655649
# Processing match 1430666908
# Processing match 1430676163
# Processing match 1430680962
# Processing match 1430681179
# Processing match 1430694938
# Processing match 1430721509
# Processing match 1430733890
# Processing match 1430744795
# Processing match 1430756334
# Processing match 1430760214
# Processing match 1430794048
# Processing match 1430802396
# Processing match 1430809008
# Processing match 1430840598
# Processing match 1430847361
# Processing match 1430913184
# Processing match 1430942076
# Processing match 1430954873
# Processing match 1430964824
# Processing match 1431010763
# Processing match 1431090785
# Processing match 1431146195
# Processing match 1431433142
# Processing match 1431475015
# Processing match 1431503671
# Processing match 1431528090
# Processing match 1431535508
# Processing match 1431578496
# Processing match 1431594285
# Processing match 1431643778
# Processing match 1431664873
# Processing match 1431715775
# Processing match 1431751418
# Processing match 1431755270
# Processing match 1431764122
# Processing match 1431767951
# Processing match 1431771014
# Processing match 1431776203
# Processing match 1431779542
# Processing match 1431783735
# Processing match 1431795741
# Processing match 1431800854
# Processing match 1431813493
# Processing match 1431827999
# Processing match 1431838551
# Processing match 1431839913
# Processing match 1431842606
# Processing match 1431858628
# Processing match 1431878620
# Processing match 1431880039
# Processing match 1432012749
# Processing match 1432014744
# Processing match 1432063604
# Processing match 1432065454
# Processing match 1432127984
# Processing match 1432217824
# Processing match 1432248920
# Processing match 1432300831
# Processing match 1432328699
# Processing match 1432330409
# Processing match 1432334163
# Processing match 1432361824
# Processing match 1432367982
# Processing match 1432382122
# Processing match 1432402520
# Processing match 1432427067
# Processing match 1432449130
# Processing match 1432502675
# Processing match 1432513401
# Processing match 1432528021
# Processing match 1432569323
# Processing match 1432590637
# Processing match 1432618092
# Processing match 1432689856
# Processing match 1432700864
# Processing match 1432747593
# Processing match 1432797218
# Processing match 1432820501
# Processing match 1432846613
# Processing match 1432847254
# Processing match 1432875213
# Processing match 1432905674
# Processing match 1432925136
# Processing match 1432976264
# Processing match 1433031050
# Processing match 1433115231
# Processing match 1433123547
# Processing match 1433145879
# Processing match 1433148600
# Processing match 1433176217
# Processing match 1433180117
# Processing match 1433180414
# Processing match 1433206893
# Processing match 1433219284
# Processing match 1433230118
# Processing match 1433234223
# Processing match 1433247109
# Processing match 1433285453
# Processing match 1433297772
# Processing match 1433317201
# Processing match 1433332656
# Processing match 1433339531
# Processing match 1433357367
# Processing match 1433419971
# Processing match 1433427395
# Processing match 1433467602
# Processing match 1433519734
# Processing match 1433549447
# Processing match 1433575575
# Processing match 1433584825
# Processing match 1433617256
# Processing match 1433640248
# Processing match 1433672371
# Processing match 1433674741
# Processing match 1433678305
# Processing match 1433715666
# Processing match 1433731832
# Processing match 1433732639
# Processing match 1433801801
# Processing match 1433811976
# Processing match 1433872136
# Processing match 1433920901
# Processing match 1433969825
# Processing match 1433995229
# Processing match 1433995752
# Processing match 1434017631
# Processing match 1434018132
# Processing match 1434056514
# Processing match 1434077491
# Processing match 1434092888
# Processing match 1434119886
# Processing match 1434132258
# Processing match 1434139159
# Processing match 1434144388
# Processing match 1434190046
# Processing match 1434209455
# Processing match 1434218035
# Processing match 1434254085
# Processing match 1434284219
# Processing match 1434313153
# Processing match 1434329199
# Processing match 1434351398
# Processing match 1434356727
# Processing match 1434364900
# Processing match 1434410354
# Processing match 1434438629
# Processing match 1434487113
# Processing match 1434540078
# Processing match 1434553365
# Processing match 1434556945
# Processing match 1434829796
# Processing match 1434941997
# Processing match 1434950834
# Processing match 1434961551
# Processing match 1434993748
# Processing match 1435005560
# Processing match 1435019933
# Processing match 1435045811
# Processing match 1435096508
# Processing match 1435096722
# Processing match 1435108681
# Processing match 1435135243
# Processing match 1435206122
# Processing match 1435225289
# Processing match 1435227788
# Processing match 1435249184
# Processing match 1435261274
# Processing match 1435297455
# Processing match 1435331334
# Processing match 1435347497
# Processing match 1435549099
# Processing match 1435577492
# Processing match 1435604301
# Processing match 1435618920
# Processing match 1435633539
# ...
# Processing match 2013707429
# Processing match 2013717776
# Processing match 2013738913
# Processing match 2013739600
# Processing match 2013743463
# Processing match 2013744590
# Processing match 2013768903
# Processing match 2013782124
# Processing match 2013788207
# Processing match 2013806893
# Processing match 2013817687
# Processing match 2013822622
# Processing match 2013837053
# Processing match 2013837228
# Processing match 2013857094
# Processing match 2013858532
# Processing match 2013869995
# Processing match 2013876169
# Processing match 2013883137
# Processing match 2013889545
# Processing match 2013897788
# Processing match 2013932195
# Processing match 2013944071
# Processing match 2013945625
# Processing match 2013990241
# Processing match 2014006234
# Processing match 2014022527
# Processing match 2014041010
# Processing match 2014044395
# Processing match 2014082030
# Processing match 2014091952
# Processing match 2014095933
# Processing match 2014207582
# Processing match 2014230275
# Processing match 2014233239
# Processing match 2014244954
# Processing match 2014280580
# Processing match 2014302126
# Processing match 2014390150
# Processing match 2014390232
# Processing match 2014419043
# Processing match 2014422236
# Processing match 2014472878
# Processing match 2014493244
# Processing match 2014496202
# Processing match 2014512268
# Processing match 2014517026
# Processing match 2014519328
# Processing match 2014546798
# Processing match 2014585705
# Processing match 2014599380
# Processing match 2014700420
# Processing match 2014761366
# Processing match 2014792263
# Processing match 2014798406
# Processing match 2014837696
# Processing match 2014864739
# Processing match 2014891606
# Processing match 2014911666
# Processing match 2014953031
# Processing match 2015033599
# Processing match 2015054289
# Processing match 2015069795
# Processing match 2015079080
# Processing match 2015127600
# Processing match 2015156104
# Processing match 2015164422
# Processing match 2015265549
# Processing match 2015340109
# Processing match 2015355974
# Processing match 2015399748
# Processing match 2015408937
# Processing match 2015452114
# Processing match 2015468786
# Processing match 2015473751
# Processing match 2015506818
# Processing match 2015528349
# Processing match 2015568851
# Processing match 2015620483
# Processing match 2015625083
# Processing match 2015636081
# Processing match 2015690741
# Processing match 2015695672
# Processing match 2015701341
# Processing match 2015703803
# Processing match 2015813201
# Processing match 2015862002
# Processing match 2015892153
# Processing match 2015971694
# Processing match 2016380236
# Processing match 2016442339
# Processing match 2016489979
# Processing match 2016499405
# Processing match 2016545394
# Processing match 2016566751
# Processing match 2016600034
# Processing match 2016643538
# Processing match 2016685819
# Processing match 2016713017
# Processing match 2016718729
# Processing match 2016728447
# Processing match 2016752322
# Processing match 2016761812
# Processing match 2016765013
# Processing match 2016942009
# Processing match 2017238339
# Processing match 2017386552
# Processing match 2017577856
# Processing match 2017606704
# Processing match 2017658136
# Processing match 2017659881
# Processing match 2017707964
# Processing match 2017748776
# Processing match 2017782692
# Processing match 2017796186
# Processing match 2017968197
# Processing match 2018031853
# Processing match 2018038961
# Processing match 2018041778
# Processing match 2018083631
# Processing match 2018126292
# Processing match 2018209729
# Processing match 2018425138
# Processing match 2018478392
# Processing match 2018553288
# Processing match 2018559040
# Processing match 2018561639
# Processing match 2018592020
# Processing match 2018597109
# Processing match 2018633503
# Processing match 2018647396
# Processing match 2018670006
# Processing match 2018676562
# Processing match 2018692172
# Processing match 2018699328
# Processing match 2018702333
# Processing match 2018702804
# Processing match 2018713127
# Processing match 2018715646
# Processing match 2018730724
# Processing match 2019275682
# Processing match 2019302610
# Processing match 2019551770
# Processing match 2019584149
# Processing match 2019590380
# Processing match 2019620232
# Processing match 2019632880
# Processing match 2019633530
# Processing match 2019646080
# Processing match 2019672803
# Processing match 2019688579
# Processing match 2019696277
# Processing match 2019703114
# Processing match 2019730656
# Processing match 2019739177
# Processing match 2019742304
# Processing match 2020156352
# Processing match 2020177720
# Processing match 2020188521
# Processing match 2020211717
# Processing match 2020218546
# Processing match 2020229607
# Processing match 2020231054
# Processing match 2020263342
# Processing match 2020315176
# Processing match 2020337748
# Processing match 2020420515
# Processing match 2020559376
# Processing match 2020607106
# Processing match 2020647687
# Processing match 2020653555
# Processing match 2020678233
# Processing match 2020681658
# Processing match 2020706237
# Processing match 2020707214
# Processing match 2020711769
# Processing match 2020727981
# Processing match 2020754559
# Processing match 2020755904
# Processing match 2020801960
# Processing match 2020804219
# Processing match 2020807063
# Processing match 2020826826
# Processing match 2020884892
# Processing match 2021070886
# Processing match 2021207767
# Processing match 2021220299
# Processing match 2021245532
# Processing match 2021257451
# Processing match 2021277668
# Processing match 2021294509
# Processing match 2021295962
# Processing match 2021321895
# Processing match 2021324755
# Processing match 2021350351
# Processing match 2021351878
# Processing match 2021363562
# Processing match 2021365563
# Processing match 2021401209
# Processing match 2021412174
# Processing match 2021430048
# Processing match 2021434254
# Processing match 2021450814
# Processing match 2021457885
# Processing match 2021459389
# Processing match 2021460240
# Processing match 2021484412
# Processing match 2021489236
# Processing match 2021494442
# Processing match 2021514459
# Processing match 2021538212
# Processing match 2021546597
# Processing match 2021608148
# Processing match 2021627916
# Processing match 2021653579
# Processing match 2021676776
# Processing match 2021695441
# Processing match 2021704963
# Processing match 2021714731
# Processing match 2021735761
# Processing match 2021752602
# Processing match 2021762245
# Processing match 2021765187
# Processing match 2021776091
# Processing match 2021800086
# Processing match 2021802695
# Processing match 2021806204
# Processing match 2021817890
# Processing match 2021826156
# Processing match 2021929662
# Processing match 2021957092
# Processing match 2021993904
# Processing match 2022031746
# Processing match 2022058389
# Processing match 2022207512
# Processing match 2022366346
# Processing match 2022370474
# Processing match 2022410102
# Processing match 2022412373
# Processing match 2022432305
# Processing match 2022433666
# Processing match 2022439363
# Processing match 2022454633
# Processing match 2022466324
# Processing match 2022476543
# Processing match 2022500165
# Processing match 2022506322
# Processing match 2022556757
# Processing match 2022604482
# Processing match 2022634905
# Processing match 2022665125
# Processing match 2022687598
# Processing match 2022720229
# Processing match 2022727925
# Processing match 2022728056
# Processing match 2022752147
# Processing match 2022764537
# Processing match 2022778850
# Processing match 2022786658
# Processing match 2022791182
# Processing match 2022810572
# Processing match 2022817903
# Processing match 2022819507
# Processing match 2022824553
# Processing match 2022837443
# Processing match 2022854660
# Processing match 2023063806
# Processing match 2023085228
# Processing match 2023113531
# Processing match 2023154776
# Processing match 2023249802
# Processing match 2023257034
# Processing match 2023257977
# Processing match 2023515238
# Processing match 2023622562
# Processing match 2023624925
# Processing match 2023678145
# Processing match 2023684480
# Processing match 2023686677
# Processing match 2023724368
# Processing match 2023731854
# Processing match 2023764666
# Processing match 2023779767
# Processing match 2023788914
# Processing match 2023799321
# Processing match 2023807660
# Processing match 2023814886
# Processing match 2023828546
# Processing match 2023836608
# Processing match 2023859295
# Processing match 2023859889
# Processing match 2023865420
# Processing match 2023881114
# Processing match 2023883197
# Processing match 2023899904
# Processing match 2023902774
# Processing match 2023909841
# Processing match 2023911766
# Processing match 2023921317
# Processing match 2023925552
# Processing match 2023928885
# Processing match 2023929844
# Processing match 2023932052
# Processing match 2023950610
# Processing match 2023962150
# Processing match 2023966117
# Processing match 2024087990
# Processing match 2024098020
# Processing match 2024138336
# Processing match 2024186089
# Processing match 2024219305
# Processing match 2024307798
# Processing match 2024346952
# Processing match 2024370085
# Processing match 2024391949
# Processing match 2024414717
# Processing match 2024435285
# Processing match 2024481718
# Processing match 2024483873
# Processing match 2024561072
# Processing match 2024566993
# Processing match 2024651928
# Processing match 2024656520
# Processing match 2024664989
# Processing match 2024748775
# Processing match 2024750323
# Processing match 2024751420
# Processing match 2024763432
# Processing match 2024768909
# Processing match 2024834193
# Processing match 2024852930
# Processing match 2024853349
# Processing match 2024873764
# Processing match 2024874690
# Processing match 2024879534
# Processing match 2024910310
# Processing match 2024950353
# Processing match 2024962291
# Processing match 2025015724
# Processing match 2025036838
# Processing match 2025040311
# Processing match 2025048096
# Processing match 2025056176
# Processing match 2025080863
# Processing match 2025083557
# Processing match 2025103183
# Processing match 2025150051
# Processing match 2025170398
# Processing match 2025217557
# Processing match 2025220176
# Processing match 2025263497
# Processing match 2025269497
# Processing match 2025271319
# Processing match 2025348258
# Processing match 2025367592
# Processing match 2025382376
# Processing match 2025387540
# Processing match 2025395354
# Processing match 2025404907
# Processing match 2025454214
# Processing match 2025475388
# Processing match 2025496223
# Processing match 2025499360
# Processing match 2025500061
# Processing match 2025518394
# Processing match 2025523468
# Processing match 2025528940
# Processing match 2025529747
# Processing match 2025542370
# Processing match 2025561648
# Processing match 2025564836
# Processing match 2025599206
# Processing match 2025615689
# Processing match 2025617965
# Processing match 2025642092
# Processing match 2025646528
# Processing match 2025647228
# Processing match 2025651250
# Processing match 2025658033
# Processing match 2025660651
# Processing match 2025664760
# Processing match 2025676555
# Processing match 2025831548
# Processing match 2025843708
# Processing match 2025942955
# Processing match 2025944854
# Processing match 2026019839
# Processing match 2026076769
# Processing match 2026077855
# Processing match 2026139414
# Processing match 2026141913
# Processing match 2026171502
# Processing match 2026232269
# Processing match 2026234662
# Processing match 2026239476
# Processing match 2026295415
# Processing match 2026315722
# Processing match 2026341926
# Processing match 2026348166
# Processing match 2026350157
# Processing match 2026357412
# Processing match 2026359514
# Processing match 2026369773
# Processing match 2026382950
# Processing match 2026385763
# Processing match 2026393668
# Processing match 2026401506
# Processing match 2026480321
# Processing match 2026484496
# Processing match 2026487789
# Processing match 2026537785
# Processing match 2026540511
# Processing match 2026543028
# Processing match 2026544648
# Processing match 2026555195
# Processing match 2026562046
# Processing match 2026567156
# Processing match 2026582109
# Processing match 2026598931
# Processing match 2026627423
# Processing match 2026638619
# Processing match 2026638910
# Processing match 2026646288
# Processing match 2026659519
# Processing match 2026666340
# Processing match 2026691343
# Processing match 2026696663
# Processing match 2026697324
# Processing match 2026737392
# Processing match 2026755752
# Processing match 2026773773
# Processing match 2026796369
# Processing match 2026821876
# Processing match 2026825429
# Processing match 2026829142
# Processing match 2026869938
# Processing match 2026884144
# Processing match 2026886735
# Processing match 2026906977
# Processing match 2026910298
# Processing match 2026918030
# Processing match 2026931072
# Processing match 2026945539
# Processing match 2026947074
# Processing match 2026960869
# Processing match 2026965142
# Processing match 2026966375
# Processing match 2026986707
# Processing match 2027007007
# Processing match 2027050100
# Processing match 2027052647
# Processing match 2027385485
# Processing match 2027410438
# Processing match 2027425234
# Processing match 2027455045
# Processing match 2027468890
# Processing match 2027498356
# Processing match 2027563475
# Processing match 2027571287
# Processing match 2027625187
# Processing match 2027717854
# Processing match 2027750250
# Processing match 2027759609
# Processing match 2027777295
# Processing match 2027792682
# Processing match 2027804328
# Processing match 2027828373
# Processing match 2027830383
# Processing match 2027832686
# Processing match 2027834549
# Processing match 2027847854
# Processing match 2027848375
# Processing match 2027863115
# Processing match 2027868702
# Processing match 2027874067
# Processing match 2027893599
# Processing match 2027985220
# Processing match 2028004603
# Processing match 2028022149
# Processing match 2028024701
# Processing match 2028028809
# Processing match 2028068714
# Processing match 2028068829
# Processing match 2028073801
# Processing match 2028099430
# Processing match 2028100102
# Processing match 2028102282
# Processing match 2028108035
# Processing match 2028128177
# Processing match 2028129189
# Processing match 2028134939
# Processing match 2028149048
# Processing match 2028163363
# Processing match 2028185914
# Processing match 2028427757
# Processing match 2028515353
# Processing match 2028630091
# Processing match 2028667574
# Processing match 2028700217
# Processing match 2028708927
# Processing match 2028722715
# Processing match 2028750370
# Processing match 2028780467
# Processing match 2028782449
# Processing match 2028830849
# Processing match 2028837784
# Processing match 2028845443
# Processing match 2028858844
# Processing match 2028884148
# Processing match 2028885874
# Processing match 2028912778
# Processing match 2028936186
# Processing match 2028963979
# Processing match 2029095049
# Processing match 2029130404
# Processing match 2029136785
# Processing match 2029153836
# Processing match 2029191052
# Processing match 2029224080
# Processing match 2029230810
# Processing match 2029242215
# Processing match 2029254650
# Processing match 2029264271
# Processing match 2029281760
# Processing match 2029284742
# Processing match 2029371544
# Processing match 2029410499
# Processing match 2029448686
# Processing match 2029455322
# Processing match 2029612049
# Processing match 2029620527
# Processing match 2029782607
# Processing match 2029865552
# Processing match 2029895421
# Processing match 2029897383
# Processing match 2029901713
# Processing match 2029936357
# Processing match 2029964678
# Processing match 2029968478
# Processing match 2029979642
# Processing match 2029986720
# Processing match 2029998302
# Processing match 2030013933
# Processing match 2030028515
# Processing match 2030047510
# Processing match 2030071922
# Processing match 2030290203
# Processing match 2030370709
# Processing match 2030386567
# Processing match 2030390622
# Processing match 2030411685
# Processing match 2030428707
# Processing match 2030441808
# Processing match 2030447837
# Processing match 2030484884
# Processing match 2030492042
# Processing match 2030513734
# Processing match 2030551638
# Processing match 2030566630
# Processing match 2030605573
# Processing match 2030691540
# Processing match 2030724309
# Processing match 2030774079
# Processing match 2030843655
# Processing match 2030883246
# Processing match 2030889730
# Processing match 2030913273
# Processing match 2030970428
# Processing match 2031001335
# Processing match 2031050322
# Processing match 2031228821

# %% [markdown]
# Now, let's create a dataframe with the pulled data by zipping the columns together.

# %%
# create the dataframe
df = pd.DataFrame(dict(zip(colnames,[fblood, fdrag, finhib, fturret, fbaron, diffdrag, diffbaron, diffcs, diffkda, 
                                     diffcc, diffspree, diffgold, diffdmg, difftank, diffrange, difftp, win])))

# %% [markdown]
# Finally, let's put this dataframe into a csv file for later use.

# %%
# export dataframe to csv
df.to_csv('newdf.csv', index=False)
